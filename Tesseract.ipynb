# %%
# !sudo apt install tesseract-ocr

# %%
# !pip install pytesseract
# !pip install numpy==1.19.5

# %%
import pytesseract
from pytesseract import image_to_string
from PIL import Image
import requests
from io import BytesIO

# %%
url='https://images.squarespace-cdn.com/content/v1/577811363e00be9cc0da688a/1467500356956-YB69H8DBSJ6Y8DBM9SGQ/TypeEd_justified_bodycopy1.png?format=1500w'
response = requests.get(url)
image0=Image.open(BytesIO(response.content))

# %%
image0
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=844x434>

# %%
extractedInformation = image_to_string(image0)
extractedInformation
# Out:
# 'Before\n\nWith his invention of the printing press, Gutenberg was\nthe first European to use movable type printing, in\naround 1439. Among his many contributions to printing\nare: the invention of a process for mass-producing\nmovable type; the use of oil-based ink; and the use of a\n‘wooden printing press similar to the agricultural screw\npresses of the period. His truly epochal invention was\nthe combination of these elements into a practical system.\nthat allowed the mass production of printed books and\n‘was economically viable for printers and readers alike.\nGutenberg’ method for making type is traditionally\nconsidered to have included a type metal alloy and a\nhand mould for casting type. The alloy was a mixture of\nlead, tin, and antimony that melted at a relatively low\n‘temperature for faster and more economical casting, cast\nwell, and created a durable type.\n\nAfter\n\nWith his invention of the printing press, Gutenberg was\n\nthe first European to use movable type pr
# ...
